# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df["Type 2"].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %% [markdown]
# Two Sample T-test

# %%
df_dragon = df[(df['Type 1']=="Dragon") | (df['Type 2']=="Dragon")]["HP"]
df_grass = df[(df['Type 1']=="Grass") | (df['Type 2']=="Grass")]["HP"]

#Set the hypothesis

#H0: mu_hp dragon <= mu_hp grass
#H1: mu_hp dragon > mu_hp grass

#significance level = 0.05

st.ttest_ind(df_dragon, df_grass, equal_var=False, alternative='greater')
# Out:
# TtestResult(statistic=4.097528915272702, pvalue=5.090769061176926e-05, df=77.58086781513519)

# %% [markdown]
# Given our pvalue being so small and lower than out significance level of 0.05, we reject the Null Hypothesis

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
df.columns.unique()
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# ANOVA Test 
#Set the hypothesis

#H0: mu_attr leg = mu_attr no_leg
#H1: mu_attr leg != mu_attr no_leg

#significance level = 0.05

attributes = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
alpha = 0.05

for attribute in attributes:
    print('\n'f'We are looking at attribute: {attribute}')
    
    df_leg = df[(df["Legendary"]==True)][attribute]
    df_no_leg = df[(df["Legendary"]==False)][attribute]
    p_value = st.ttest_ind(df_leg, df_no_leg,  equal_var=False)[1]
    print(f' p_value = {p_value}')
    if p_value > alpha:
        print("We are not able to reject the null hypothesis")
    else:
        print("We reject the null hypotesis")
# Out:
# We are looking at attribute: HP
#  p_value = 1.0026911708035284e-13
# We reject the null hypotesis
#
# We are looking at attribute: Attack
#  p_value = 2.520372449236646e-16
# We reject the null hypotesis
#
# We are looking at attribute: Defense
#  p_value = 4.8269984949193316e-11
# We reject the null hypotesis
#
# We are looking at attribute: Sp. Atk
#  p_value = 1.5514614112239812e-21
# We reject the null hypotesis
#
# We are looking at attribute: Sp. Def
#  p_value = 2.2949327864052826e-15
# We reject the null hypotesis
#
# We are looking at attribute: Speed
#  p_value = 1.049016311882451e-18
# We reject the null hypotesis

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 37)
# - Hospital coordinates (-122, 34)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
sch_coor=(-118, 37) #(longitude,latitude)
hos_coor=(-122, 34)

# df['latitude']
# df['longitude']

# # Calculate Euclidean Distance
def school_eu_dis(df, sch_coor):
    s_eu_dis= np.sqrt((df['longitude']-sch_coor[0])**2 + (df['latitude']-sch_coor[1])**2)
    return s_eu_dis

distance1 = round(school_eu_dis(df, sch_coor),2)
df['dist2school']= distance1

def hospi_eu_dis(df, hos_coor):
    h_eu_dis= np.sqrt((df['longitude']-hos_coor[0])**2 + (df['latitude']-hos_coor[1])**2)
    return h_eu_dis

distance2 = round(hospi_eu_dis(df, hos_coor),2)
df['dist2hospi']= distance2

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df['dist2school']
# Out:
# 0        4.64
# 1        4.38
# 2        4.77
# 3        4.80
# 4        4.85
#          ...
# 16995    7.21
# 16996    7.28
# 16997    7.94
# 16998    7.92
# 16999    7.27
# Name: dist2school, Length: 17000, dtype: float64

# %%
print(df.dist2school.describe())  #just to check the min and max of each distance
print(df.dist2hospi.describe())
# Out:
# count    17000.000000
# mean         3.487085
# std          0.870758
# min          0.320000
# 25%          2.970000
# 50%          3.240000
# 75%          4.140000
# max          7.940000
# Name: dist2school, dtype: float64
# count    17000.000000
# mean         4.061724
# std          0.820062
# min          1.570000
# 25%          3.630000
# 50%          3.870000
# 75%          4.490000
# max          8.230000
# Name: dist2hospi, dtype: float64

# %% [markdown]
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.

# %%
df_closeby=df[(df['dist2school']<= 0.50) | (df['dist2hospi'] <= 0.50)]
df_closeby
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4523    -118.05     36.64                34.0       2090.0           478.0
# 5596    -118.18     37.35                16.0       3806.0           794.0
# 5597    -118.18     36.63                23.0       2311.0           487.0
# 6776    -118.30     37.17                22.0       3480.0           673.0
# 6904    -118.31     36.94                35.0       2563.0           530.0
#
#       population  households  median_income  median_house_value  dist2school  \
# 4523       896.0       426.0         2.0357             74200.0         0.36
# 5596      1501.0       714.0         2.1212            108300.0         0.39
# 5597      1019.0       384.0         2.2574            104700.0         0.41
# 6776      1541.0       636.0         2.7500             94500.0         0.34
# 6904       861.0       371.0         2.3250             80600.0         0.32
#
#       dist2hospi
# 4523        4.75
# ...

# %%
df_farland=df[(df['dist2school']> 0.50) | (df['dist2hospi'] > 0.50)]
df_farland
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# Hypothesis to test: We posit that houses close to either a school or a hospital are more expensive.

# %%
#Set the hypothesis


#H0: mu_median_house_value closeby <= mu_median_house_value farland
#H1: mu_median_house_value closeby > mu_median_house_value farland

#significance level = 0.05

df_closeby=df[(df['dist2school']<= 0.50) | (df['dist2hospi'] <= 0.50)]['median_house_value']
df_farland=df[(df['dist2school']> 0.50) | (df['dist2hospi'] > 0.50)]['median_house_value']

st.ttest_ind(df_closeby, df_farland, equal_var=False, alternative='greater')

pvalue = st.ttest_ind(df_closeby, df_farland, equal_var=False, alternative='greater')[1]
print('\n',f'pvalue: {pvalue}')
# Out:
#  pvalue: 0.9999738667251178

# %% [markdown]
# With the current p_value, we fail to reject the null hypothesis, therefore the distance to school or hospital doesn't necessarily have an impact in the prices.
